# %%
import pandas as pd

# %%
data=pd.read_csv('C:\Users\HP\Desktop\crypto-classifier\data\processed\crypto_data_labeled.csv', parse_dates=['Date'], index_col='Date')
# Out:
#   Cell In[3], line 1
#     data=pd.read_csv('C:\Users\HP\Desktop\crypto-classifier\data\processed\crypto_data_labeled.csv', parse_dates=['Date'], index_col='Date')
#                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #save the data to a new csv file
# ----> 2 data.read_csv('data/processed/crypto_data_cleaned.csv', parse_dates=['Date'], index_col='Date')
#
# NameError: name 'data' is not defined

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.shape
#
# NameError: name 'data' is not defined
